# %% [markdown]
# <a href="https://colab.research.google.com/github/asarria48/HerrComp/blob/main/PLOTS_SarriaAlejandra_S7C2_EDO2_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
datEuler = np.genfromtxt("euler.dat", delimiter=",");
plt.plot(datEuler[:,0], datEuler[:,1])
plt.show()

datLeapfrog = np.genfromtxt("leapfrog.dat", delimiter=",");
plt.plot(datLeapfrog[:,0], datLeapfrog[:,1])
plt.show()
